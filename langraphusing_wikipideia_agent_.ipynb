# %%
# !pip install --upgrade langchain langchain-community langgraph google-generativeai wikipedia

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
api_Wrapper=WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=300)
wiki_tool=WikipediaQueryRun(api_wrapper=api_Wrapper)

# %%
wiki_tool.run({'query':"ai agent"})
# Out:
# 'Page: AI agent\nSummary: In the context of generative artificial intelligence, AI agents (also referred to as compound AI systems or agentic AI) are a class of intelligent agents distinguished by their ability to operate autonomously in complex environments. Agentic AI tools prioritize decision-makin'

# %%
# !pip install --upgrade langchain-google-genai google-generativeai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=0,
    google_api_key="AIzaSyCXSf1b6PvhIk9OLERzdYfwRDwAsXVSHIk"
)

# %%
tools=[wiki_tool]
llm_with_tools=llm.bind_tools(tools)
result=llm_with_tools.invoke("hello world!")
result
result.content
# Out:
# [{'type': 'text',
#   'text': 'Hello! How can I help you today?',
#   'extras': {'signature': ''}}]

# %%
from langgraph.prebuilt import create_react_agent
agent_executor=create_react_agent(llm,tools)
# Out:
# /tmp/ipython-input-1808480343.py:2: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor=create_react_agent(llm,tools)

# %%
from langchain_core.messages import HumanMessage

#First up, let's see how it responds when there's no need to call a tool:
response = agent_executor.invoke({"messages": [HumanMessage(content="hi!")]})

response["messages"]
# Out:
# [HumanMessage(content='hi!', additional_kwargs={}, response_metadata={}, id='3949277d-0747-48a6-b5dc-14fca763813d'),
#  AIMessage(content=[{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ba6d7-46d3-7a11-87ba-670cdbdd7cf9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 44}})]

# %%
print(response["messages"][-1].content)

Hello! How can I assist you today?

from langchain_core.messages import HumanMessage

#First up, let's see how it responds when there's no need to call a tool:
response = agent_executor.invoke({"messages": [HumanMessage(content="what is agentic ai")]})

response["messages"]
# Out:
# [{'type': 'text', 'text': 'Hello! How can I help you today?', 'extras': {'signature': ''}}]
# Object `today` not found.
# [HumanMessage(content='what is agentic ai', additional_kwargs={}, response_metadata={}, id='c8f6eaac-2208-46fe-85d5-e71dc8b19e1c'),
# ...

# %%
print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': '**Agentic AI** refers to artificial intelligence systems that can reason, plan, and take autonomous actions to achieve a specific goal.\n\nWhile traditional AI (like a standard chatbot) is **reactive**—meaning it waits for a prompt and provides a response—Agentic AI is **proactive**. It doesn\'t just talk about a task; it uses tools and makes decisions to complete the task from start to finish.\n\nHere is a breakdown of what makes AI "agentic," how it works, and why it matters.\n\n---\n\n### 1. The Core Difference: Chatbot vs. Agent\n*   **Non-Agentic AI (The Thinker):** You ask, "What is the weather in Tokyo?" The AI searches its training data or a single tool and tells you. It stops there.\n*   **Agentic AI (The Doer):** You say, "I want to go to Tokyo next month. Find me a flight under $1,000, book a hotel near Shibuya, and add the itinerary to my calendar." The AI breaks this down into steps, uses various websites/APIs, handles the booking, and updates 
# ...
